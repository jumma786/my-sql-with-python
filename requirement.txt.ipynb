# %%
# Create a requirements.txt file for the user's Python + MySQL + data analysis projects
import pypandoc, os

text = """
pandas
mysql-connector-python
requests
beautifulsoup4
jupyter
"""

path = "/mnt/data/requirements.txt"
pypandoc.convert_text(text, 'plain', format='md', outputfile=path, extra_args=['--standalone'])

path
